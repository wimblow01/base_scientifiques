# %% [markdown]
# # Présentation publications Baptiste, Eva, Jérémy

# %%
from connexion import Connexion
from pprint import pprint

# %% [markdown]
# #### Compter le nombre de documents de la collection publis

# %%
print(f"Il y a {Connexion.get_number()} publications dans la bdd")
# Out:
# Il y a 15000 publications dans la bdd

# %% [markdown]
# #### Lister tous les livres (type “Book”)

# %%
pprint(Connexion.get_book()[:1])
# Out:
# [{'_id': 'series/cogtech/FurnkranzGL12',
#   'authors': ['Johannes F?rnkranz', 'Dragan Gamberger', 'Nada Lavrac'],
#   'isbn': ['978-3-540-75196-0'],
#   'pages': {'end': 298, 'start': 1},
#   'publisher': 'Springer',
#   'series': 'Cognitive Technologies',
#   'title': 'Foundations of Rule Learning',
#   'type': 'Book',
#   'url': 'http://dx.doi.org/10.1007/978-3-540-75197-7',
#   'year': 2012}]

# %% [markdown]
# #### Lister les livres depuis 2014

# %%
pprint(Connexion.get_books_2014()[:5])
# Out:
# [{'title': 'Language Processing with Perl and Prolog - Theories, '
#            'Implementation, and Application',
#   'year': 2014},
#  {'title': 'Disentangling Participation - Power and Decision-making in '
#            'Participatory Design',
#   'year': 2014},
#  {'title': 'Probabilistic Approaches to Robotic Perception.', 'year': 2014},
#  {'title': 'Visual Control of Wheeled Mobile Robots - Unifying Vision and '
#            'Control in Generic Approaches',
#   'year': 2014},
#  {'title': 'Approaching Human Performance - The Functionality-Driven Awiwi '
#            'Robot Hand',
#   'year': 2014}]

# %% [markdown]
# #### Lister les publications de l’auteur “Toru Ishida”

# %%
pprint(Connexion.get_publi_ishida())
# Out:
# [{'title': 'Integrating Smart Classroom and Language Services.'},
#  {'title': 'Collaborative Translation Protocols.'},
#  {'title': 'Pipelining Software and Services for Language Processing.'},
#  {'title': 'Exploring Cultural Differences in Pictogram Interpretations.'},
#  {'title': 'Service Supervision for Runtime Service Management.'},
#  {'title': 'Federated Operation Model for Service Grids.'},
#  {'title': 'Cascading Translation Services.'},
#  {'title': 'Service Grid Architecture.'},
#  {'title': 'Conversational Grounding in Machine Translation Mediated '
#            'Communication.'},
#  {'title': 'The Language Grid: Service-Oriented Approach to Sharing Language '
#            'Resources.'},
#  {'title': 'Multi-Language Discussion Platform for Wikipedia Translation.'},
#  {'title': 'Horizontal Service Composition for Language Services.'},
#  {'title': 'Positive and Negative Effects of Environmental Chemicals on Brain '
#            'Function in Rodents.'}]

# %% [markdown]
# #### Lister tous les auteurs distincts

# %%
pprint(Connexion.get_authors()[200:210])
# Out:
# ['Abhishek Verma',
#  'Abhranil Maiti',
#  'Abid Yahya',
#  'Abigail Sellen',
#  'Aboul Ella Hassanien',
#  'Abraham Albert Ungar',
#  'Abraham Bagherjeiran',
#  'Abraham Bernstein',
#  'Abraham Duarte',
#  'Abraham Kandel']

# %% [markdown]
# #### Trier les publications de “Toru Ishida” par titre de livre

# %%
pprint(Connexion.get_publi_ishida_croiss())
# Out:
# [{'title': 'Cascading Translation Services.'},
#  {'title': 'Collaborative Translation Protocols.'},
#  {'title': 'Conversational Grounding in Machine Translation Mediated '
#            'Communication.'},
#  {'title': 'Exploring Cultural Differences in Pictogram Interpretations.'},
#  {'title': 'Federated Operation Model for Service Grids.'},
#  {'title': 'Horizontal Service Composition for Language Services.'},
#  {'title': 'Integrating Smart Classroom and Language Services.'},
#  {'title': 'Multi-Language Discussion Platform for Wikipedia Translation.'},
#  {'title': 'Pipelining Software and Services for Language Processing.'},
#  {'title': 'Service Grid Architecture.'},
#  {'title': 'Service Supervision for Runtime Service Management.'},
#  {'title': 'The Language Grid: Service-Oriented Approach to Sharing Language '
#            'Resources.'}]

# %% [markdown]
# #### Compter le nombre de ses publications

# %%
print(f"Toru Ishida a publié {Connexion.get_number_ishida()} ouvrages")
# Out:
# Toru Ishida a publié 12 ouvrages

# %% [markdown]
# #### Compter le nombre de publications depuis 2011 et par type

# %%
pprint(Connexion.get_books_2011_type())
# Out:
# {'Article': 4441, 'Book': 890}

# %% [markdown]
# #### Compter le nombre de publications par auteur et trier le résultat par ordre croissant

# %%
pprint(Connexion.get_count_publi_author()[-10:])
# Out:
# [{'_id': {'authors': 'Vladik Kreinovich'}, 'count': 24},
#  {'_id': {'authors': 'Lakhmi C. Jain'}, 'count': 25},
#  {'_id': {'authors': 'Kevin D. Ashley'}, 'count': 25},
#  {'_id': {'authors': 'Henry Prakken'}, 'count': 25},
#  {'_id': {'authors': 'Andr? Carlos Ponce Leon Ferreira de Carvalho'},
#   'count': 27},
#  {'_id': {'authors': 'Trevor J. M. Bench-Capon'}, 'count': 31},
#  {'_id': {'authors': 'Ajith Abraham'}, 'count': 31},
#  {'_id': {'authors': 'Teresa Bernarda Ludermir'}, 'count': 32},
#  {'_id': {'authors': 'Patricia Melin'}, 'count': 69},
#  {'_id': {'authors': 'Oscar Castillo'}, 'count': 84}]

# %% [markdown]
# ## Les jolis schémas, on peut faire plein de choses !!!

# %% [markdown]
# ![camembert.PNG](attachment:camembert.PNG)

# %% [markdown]
# Publication par type par année

# %% [markdown]
# ![canvas.png](attachment:canvas.png)

# %% [markdown]
# ![canvas2.png](attachment:canvas2.png)
